# %% [markdown]
# ### What is Pandas?
# - Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, build on top of the Python programming language.

# %% [markdown]
# ### Pandas Series
# - A pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from List

# %%
#String
''' Values are manually provided, but index are given automatically'''
country = ['India', 'Pakistan', 'USA', 'Neapl', 'Sri lanka']
pd.Series(country)
# It gives info about the index and values
# Out:
# 0        India
# 1     Pakistan
# 2          USA
# 3        Neapl
# 4    Sri lanka
# dtype: object

# %%
#integers
runs = [13,24,69,45,71]
pd.Series(runs)
# Out:
# 0    13
# 1    24
# 2    69
# 3    45
# 4    71
# dtype: int64

# %%
#custom index
marks = [67,57,89,100]
subject = ['maths', 'english', 'science', 'hindi']
pd.Series(marks, index = subject)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
#Setting a name
marks1 = pd.Series(marks, index = subject, name = "Rahul ki file")
marks1
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Rahul ki file, dtype: int64

# %% [markdown]
# ### Series from dictionary

# %%
marks = {'maths': 67, 
        'english':57,
        'science':89,
        'hindi':100}
marks_series = pd.Series(marks, name = 'Rahul ke marks')
marks_series
#Here name is the attribute of the marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Rahul ke marks, dtype: int64

# %% [markdown]
# ## Series attribute

# %%
# Size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'Rahul ke marks'

# %%
#is unique 
marks_series.is_unique
pd.Series([1,1,2,3,4,5]).is_unique
#return false, beacuse 1 is repeating twice
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
#values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
#with one column
type(pd.read_csv('BollywoodActorRanking.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('BollywoodActorRanking.csv')
data
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0                  NaN
# 300      673     Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# ...

# %%
# type(subs)
#here my dtpe is still dataframe, because i have multiple columns here

# %%
''' with 2 columns'''
#subs1 = pd.read_csv('BollywoodActorRanking.csv',index_col = 'column name' squeeze=True)
# Out:
# ' with 2 columns'

# %%
# head 
data.head()
#By default provide the top 5 values in your dataframe, but can be changed the value
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
#sample
# random selection
data.sample()
# data.sample(5)
# Out:
#     actorId    actorName  movieCount  ratingSum  normalizedMovieRank  \
# 26      399  Anil Kapoor          19        790              3.11098
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 26     1930000               5.97554           5.60875

# %%
data
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0                  NaN
# 300      673     Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# ...

# %%
# values_counts -> data
data.value_counts()
# Out:
# actorId  actorName         movieCount  ratingSum  normalizedMovieRank  googleHits  normalizedGoogleRank  normalizedRating
# 373      Aamir Khan        11          1170       9.44862              2460000     7.34283               10.00000            1
# 374      Shah Rukh Khan    23          2000       7.55009              2670000     7.88458               9.22674             1
# 375      Salman Khan       36          2340       5.40217              3490000     10.00000              9.20821             1
# 376      Katrina Kaif      17          1640       8.48082              2120000     6.46570               8.94852             1
# 377      Deepika Padukone  16          1080       5.64674              3000000     8.73591               8.62716             1
#                                                                                                                             ..
# ...

# %% [markdown]
# ### short_values -> inplace
# ### data.sort_values(ascending = False).head(1).values[0]
# '''Upper code will give the value of the least number'''

# %%
#sort_index
data.sort_index(inplace = True)

# %%
data
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0                  NaN
# 300      673     Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# ...

# %% [markdown]
# ## Series Maths Methods

# %%
#count
data['actorId'].count()
# Out:
# np.int64(301)

# %%
data['ratingSum'].mean()
# Out:
# np.float64(419.13621262458474)

# %%
data['ratingSum'].median()
# Out:
# np.float64(260.0)

# %%
print(data['actorName'].mode())
#.var()
#.std()
# Out:
# 0             Aamir Khan
# 1         Aarti Chhabria
# 2      Aashish Chaudhary
# 3          Abhay Bhargav
# 4             Abhay Deol
#              ...
# 296            Yash Tonk
# 297       Yashpal Sharma
# 298      Yuvika Chaudhry
# 299        Zakir Hussain
# 300           Zayed Khan
# Name: actorName, Length: 301, dtype: object

# %%
data.describe()
# Out:
#           actorId  movieCount    ratingSum  normalizedMovieRank    googleHits  \
# count  301.000000  301.000000   301.000000           299.000000  3.010000e+02
# mean   523.000000   10.232558   419.136213             2.768970  3.741886e+05
# std     87.035433    8.508764   446.972689             1.626970  6.647169e+05
# min    373.000000    0.000000     0.000000             1.000000  0.000000e+00
# 25%    448.000000    5.000000   140.000000             1.489130  0.000000e+00
# 50%    523.000000    7.000000   260.000000             2.369570  7.640000e+04
# 75%    598.000000   12.000000   500.000000             3.621045  3.850000e+05
# max    673.000000   54.000000  2950.000000            10.000000  3.490000e+06
#
#        normalizedGoogleRank  normalizedRating
# count            189.000000        301.000000
# mean               2.533937          2.933339
# std                1.951501          1.747883
# min                1.000000          1.000000
# ...

# %% [markdown]
# ### Series indexing

# %%
#integer indexing
x = pd.Series([12,13,14,35,42,81,9,79])
x[0]
# Out:
# np.int64(12)

# %%
#negative indexing
x[-1]
#Doesn't work in negative indexing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\rahul\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 2
#       1 #negative indexing
# ----> 2 x[-1]
#       3 #Doesn't work in negative indexing
#
# File c:\Users\rahul\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
# ...

# %%
#Slicing
marks_series[0:3]
# Out:
# maths       67
# english    100
# science     89
# Name: Rahul ke marks, dtype: int64

# %%
#negative slicing
marks_series[::2]
# Out:
# maths      67
# science    89
# Name: Rahul ke marks, dtype: int64

# %% [markdown]
# ### Editing series

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Rahul ke marks, dtype: int64

# %%
#using indexing
marks_series[1] = 100
marks_series
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_57932\3308855498.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: Rahul ke marks, dtype: int64

# %%
#What if an index does not exist
marks_series['sst'] = 90
# it will not through error while wrting, and make a new element

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         90
# Name: Rahul ke marks, dtype: int64

# %%
#slicing
"""runs_ser[2:4] = [100,100]
runs_ser"""
# Out:
# 'runs_ser[2:4] = [100,100]\nruns_ser'

# %% [raw]
# #using index label
# data['2 States(2014)'] = 'Alia bhatt
# data

# %% [markdown]
# ## Series with PythonFunctionalities

# %%
#len/type/dir/sorted/max/min
print(len(data))
# Out:
# 301

# %%
#type conversion
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         90
# Name: Rahul ke marks, dtype: int64

# %%
list(marks_series)
# Out:
# [67, 100, 89, 100, 90]

# %%
#membership operator
' 2 States (2014)' in data
# Out:
# False

# %%
'Alia Bhatt' in data
#both wrong
# Out:
# False

# %%
#Arithmatic operators(Broadcasting)
100 + marks_series
# Out:
# maths      167
# english    200
# science    189
# hindi      200
# sst        190
# Name: Rahul ke marks, dtype: int64

# %%
marks_series >= 160
# Out:
# maths      False
# english    False
# science    False
# hindi      False
# sst        False
# Name: Rahul ke marks, dtype: bool

# %% [markdown]
# ## Plotting Graph on Series

# %%
data.plot()
# Out:
# <Axes: >

# %% [raw]
# movies.value_counts().head(20).plot(kind='bar')

# %% [markdown]
# # Data Frame

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating data frame

# %%
#using list
student_data = [
    [100,80,10],
    [90,70, 7],
    [120,80,2]
]
pd.DataFrame(student_data, columns = ['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120     80        2

# %%
#using dictionary
stu_dic = {'iq': [100,90,84,22],
          'marks': [80,70,100,50],
          'package':[10,7,14,2]
          }
students = pd.DataFrame(stu_dic)

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl =  pd.read_csv('ipl-matches.csv')
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
#dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# top 5 ipl matches
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.sample(5)
# Out:
#          ID    City        Date   Season  MatchNumber             Team1  \
# 381  981003  Raipur  2016-05-20     2016           52  Delhi Daredevils
# 374  981017   Delhi  2016-05-27     2016  Qualifier 2     Gujarat Lions
# 917  336015  Jaipur  2008-05-11  2007/08           33  Rajasthan Royals
# 823  419116   Delhi  2010-03-19  2009/10           11  Delhi Daredevils
# 661  548349  Jaipur  2012-05-01     2012           43  Rajasthan Royals
#
#                    Team2                                             Venue  \
# 381  Sunrisers Hyderabad  Shaheed Veer Narayan Singh International Stadium
# 374  Sunrisers Hyderabad                                  Feroz Shah Kotla
# 917     Delhi Daredevils                            Sawai Mansingh Stadium
# 823  Chennai Super Kings                                  Feroz Shah Kotla
# 661     Delhi Daredevils                            Sawai Mansingh Stadium
#
#               TossWinner TossDecision SuperOver          WinningTeam    WonBy  \
# ...

# %%
#info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#number of duplicated values in the dataframe
movies.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### renaming the columns
# ### data.rename(columns={'marks':'percentage', 'package':'lpa'}, inplace = True)

# %% [markdown]
# ### Mathmatical function

# %%
''' sum for adding all the dada values'''
# Out:
# ' sum for adding all the dada values'

# %% [raw]
# # data.mean(axis=1)
# # data.median(axis=1)
# # data.variance(axis=1)

# %%
#fettiching single column
movies['title_x']
#here type will be Series
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
#fetching more than 1 column
movies[['title_x','year_of_release','tagline']]
#here type will be DataFrame
# Out:
#                                    title_x  year_of_release tagline
# 0                 Uri: The Surgical Strike             2019     NaN
# 1                            Battalion 609             2019     NaN
# 2     The Accidental Prime Minister (film)             2019     NaN
# 3                          Why Cheat India             2019     NaN
# 4                          Evening Shadows             2018     NaN
# ...                                    ...              ...     ...
# 1624                 Tera Mera Saath Rahen             2001     NaN
# 1625                  Yeh Zindagi Ka Safar             2001     NaN
# 1626                       Sabse Bada Sukh             2018     NaN
# 1627                                 Daaka             2019     NaN
# 1628                              Humsafar             2011     NaN
#
# [1629 rows x 3 columns]

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
# making dataframe using dictionary
stu = {
    'name':['Rahul','Vivek','Swayam','Rohit','Ram'],
    'iq':[100,90,120,80,0],
    'marks':[61,69,56,77,99],
    'package':[10,7,4,6,9]
}
students = pd.DataFrame(stu)
# Set 'name' as the index
students.set_index('name', inplace=True)

# %% [raw]
# ### Select rows from a DataFrame
# - iloc:- searches using index positions
# - loc:- searches using index labels

# %%
#single row
movies.iloc[0]
#it will be Series
# works in searches using index positions
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
#multiple
movies.iloc[0:5]
#it will be a DataFrame
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#fancy indexing
movies.iloc[0:10:2]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 2  The Accidental Prime Minister (film)  tt6986710
# 4                       Evening Shadows  tt6028796
# 6                         Fraud Saiyaan  tt5013008
# 8      Manikarnika: The Queen of Jhansi  tt6903440
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 8  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 6        https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 8  https://en.wikipedia.org/wiki/Manikarnika:_The...
#
# ...

# %%
students
# Out:
#          iq  marks  package
# name
# Rahul   100     61       10
# Vivek    90     69        7
# Swayam  120     56        4
# Rohit    80     77        6
# Ram       0     99        9

# %%
# loc works on index labels
students.loc['Rahul']
# Out:
# iq         100
# marks       61
# package     10
# Name: Rahul, dtype: int64

# %%
 #last calue also included
students.loc['Rahul': 'Rohit']
# Out:
#          iq  marks  package
# name
# Rahul   100     61       10
# Vivek    90     69        7
# Swayam  120     56        4
# Rohit    80     77        6

# %%
#First 3 movies of first 3 columns
movies.head(3)[movies.columns[:3]]
#OR
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.iloc[:3, :3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#find all the final winner
mask = ipl['MatchNumber']== 'Final'
new_df = ipl[mask]
new_df[['Season','WinningTeam']]

#OR
# ipl[ipl['MatchNumber']== 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl['SuperOver'].head()
# Out:
# 0    N
# 1    N
# 2    N
# 3    N
# 4    N
# Name: SuperOver, dtype: object

# %%
#how many super over finishes have occured
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
# How many matches has CSK won in Kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
#toss winnner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
# Movies with rating higher than 8.5 and votes>10000
movies[(movies['imdb_rating']>8.5) & (movies['imdb_votes']> 10000)].shape[0]
# Out:
# 0

# %%
#Action movies with rating higher tahn 7.5
mask1 = movies['genres'].str.split('|').apply(lambda x : 'Action' in x)
mask2 = movies['imdb_rating'] > 7.5
movies[mask1 & mask2].shape[0]
# Out:
# 33

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [raw]
# #write a function that can return the track record of 2 teams against each other
# def get_team_record(team1, team2, matches):
#     """
#     Computes the track record between two teams from the matches DataFrame.
#
#     Parameters:
#         team1 (str): Name of the first team (e.g., 'Royal Challengers Bangalore').
#         team2 (str): Name of the second team (e.g., 'Chennai Super Kings').
#         matches (pd.DataFrame): The DataFrame containing match details.
#
#     Returns:
#         pd.DataFrame: Summary of matches played, wins, and no results/draws.
#     """
#     # Filter matches where the two teams played against each other
#     head_to_head = matches[
#         ((matches['Team1'] == team1) & (matches['Team2'] == team2)) |
#         ((matches['Team1'] == team2) & (matches['Team2'] == team1))
#     ]
#
#     # Calculate total matches
#     total_matches = len(head_to_head)
#
#     # Calculate wins for each team
#     team1_wins = (head_to_head['WinningTeam'] == team1).sum()
#     team2_wins = (head_to_head['WinningTeam'] == team2).sum()
#
#     # Calculate no results/draws
#     no_results = total_matches - (team1_wins + team2_wins)
#
#     # Create a summary
#     summary = {
#         'Total Matches': total_matches,
#         f'{team1} Wins': team1_wins,
#         f'{team2} Wins': team2_wins,
#         'No Results/Draws': no_results
#     }
#
#     return pd.DataFrame([summary])
#
# # Example Usage
# team1 = 'Royal Challengers Bangalore'
# team2 = 'Chennai Super Kings'
#
# record = get_team_record(team1, team2, matches)
# record

# %% [markdown]
# ### Adding new columns

# %%
#Completely new
movies['Country'] = 'India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#removing missing values from actors
movies.dropna(subset=['actors'], inplace=True)

# %%
#From existing one
movies['lead_actors'] = movies['actors'].str.split('|').apply(lambda x:x[0])
movies['lead_actors']
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1624          Ajay Devgn
# 1625       Ameesha Patel
# 1626         Vijay Arora
# 1627        Gippy Grewal
# 1628          Fawad Khan
# Name: lead_actors, Length: 1624, dtype: object

# %% [markdown]
# ### Important dataframe functions

# %%
#astype
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# value_counts
# sort_values
# rank
# sort_index
# set index
# rename index -> index
# reset index
# unique & nunique
# isnull/ notnull/ hasnans
# dropna
# fillna
# drop_duplicates
# drop
# apply
# isin
# corr
# nlargest -> nsmallest
# insert
# copy

# %%
# value_counts[series, dataframes]
a = pd.Series([1,1,1,2,3])
a.value_counts()
# Out:
# 1    3
# 2    1
# 3    1
# Name: count, dtype: int64

# %%
#find which player has won most potm -> in finals and qualifiers
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
#Toss decision plot
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
ipl.sample(1)
# Out:
#           ID           City        Date Season MatchNumber           Team1  \
# 195  1181767  Visakhapatnam  2019-05-10   2019   Qualifier  Delhi Capitals
#
#                    Team2                                              Venue  \
# 195  Chennai Super Kings  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
#
#               TossWinner TossDecision SuperOver          WinningTeam    WonBy  \
# 195  Chennai Super Kings        field         N  Chennai Super Kings  Wickets
#
#      Margin method Player_of_Match  \
# 195     6.0    NaN    F du Plessis
#
#                                           Team1Players  \
# 195  ['PP Shaw', 'S Dhawan', 'C Munro', 'SS Iyer', ...
#
#                                           Team2Players       Umpire1 Umpire2
# 195  ['F du Plessis', 'SR Watson', 'SK Raina', 'AT ...  BNJ Oxenford  S Ravi

# %%
# how many matches each team has played
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending = False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sort_values(series and dataframes)
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.sort_values('title_x', ascending=True).head(5)
# Out:
#                      title_x    imdb_id  \
# 1498      16 December (film)  tt0313844
# 1021             1920 (film)  tt1301698
# 287             1920: London  tt5638500
# 723   1920: The Evil Returns  tt2222550
# 1039        1971 (2007 film)  tt0983990
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link             title_y  \
# 1498   https://en.wikipedia.org/wiki/16_December_(film)              16-Dec
# 1021          https://en.wikipedia.org/wiki/1920_(film)                1920
# 287           https://en.wikipedia.org/wiki/1920_London         1920 London
# ...

# %%
#set_index(dataframe) -> inplace
batsman = pd.read_csv('batsman_runs_ipl.csv')
batsman
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman.set_index('batter', inplace= True)

# %%
#reset_index(Series, DataFrame) -> drop parameter
batsman.reset_index(inplace = True)

# %%
#Series to dataframe using reset_index
marks_series.reset_index()
# Out:
#      index  Rahul ke marks
# 0    maths              67
# 1  english              57
# 2  science              89
# 3    hindi             100

# %%
movies.rename(columns = {'imdb_id':'imdb', 'poster_path':'link'}, inplace = True)

# %%
movies.rename(index = {'Uri: The Surgical Strike':'Uri', 'Battalion 609':'Battalion'}, inplace = True)

# %% [markdown]
# #### Unique

# %%
#unique(Series)
temp = pd.Series([1,1,2,4,5,7,1,6,np.nan])
temp.unique()
# Out:
# array([ 1.,  2.,  4.,  5.,  7.,  6., nan])

# %%
# unique count the null value also
len(temp.unique())
# Out:
# 7

# %%
# no null values are taken here
temp.nunique()
# Out:
# 6

# %% [raw]
# # isnull( Series + DataFrame)
# # notnull reverse of isnull (Series + DataFrame)
# # hasnans (Series only) tell us if it has nan values

# %% [raw]
# # data.dropna(subset=['column_name'], inplace=True)

# %% [raw]
# # students['name'].fillna(method = 'ffill')
# or
# students['name'].fillna(method = 'bfill')
#
# ''' ffill means the forward fill, bfill means the backward fill'''
# they will fill the next or the previous value in the NaN area

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# find the last match played by virat kohli in Delhi
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.sample()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # find the last match played by virat kohli in Delhi
# ----> 2 ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
#       3 ipl.sample()
#
# NameError: name 'ipl' is not defined

# %%
def did_kohli_played(players_list):
    return 'V kohli' in players_list

ipl['did_kohli_played'] = ipl['all_players'].apply(did_kohli_played)

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_played'] == True)].drop_duplicates(subset = ['city', 'did_kohli_play'],keep = 'first')
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2, all_players, did_kohli_played]
# Index: []
#
# [0 rows x 22 columns]

# %%
# drop(Series + dataframe)
temp = pd.Series([10,2,21,7,96,6969])
temp
# Out:
# 0      10
# 1       2
# 2      21
# 3       7
# 4      96
# 5    6969
# dtype: int64

# %%
temp.drop(index=[0,5])
# Out:
# 1     2
# 2    21
# 3     7
# 4    96
# dtype: int64

# %% [markdown]
# #### Here drop is used to drop the entire columns
# - students.drop(columns=['branch', 'cgpa'])

# %% [markdown]
# #### Apply (series + dataframe)

# %%
temp = pd.Series([10,20,30,40,50])
temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
def sigmoit(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoit)
# Out:
# 0    1.000045
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df

# %%
def euclidean(row):
  pt_A = row['1st point']
  pt_B = row['2nd point']

  return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(euclidean,axis=1)
points_df

# %%
# isin(series)
# corr
# nlargest and nsmallest(series and dataframe)
# insert(dataframe)
# copy(series + dataframe)
