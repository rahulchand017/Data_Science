# %%
import pandas as  pd

# %%
marks = [67,82,91,52]
pd.Series(marks, name ="My marks")
# Out:
# 0    67
# 1    82
# 2    91
# 3    52
# Name: My marks, dtype: int64

# %%
#custom index
marks = [67,57,89,100]
subject = ['maths', 'english', 'science', 'hindi']
overall = pd.Series(marks, index = subject)
overall
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
import pandas as pd

number = [1, 2, 1, 4, 5, 6, 7]
pd.Series(number).is_unique
# Out:
# False

# %%
import numpy as np

# %%
#unique(Series)
temp = pd.Series([1,1,2,4,5,7,1,6, np.nan])
temp.unique()
# Out:
# array([ 1.,  2.,  4.,  5.,  7.,  6., nan])

# %%
# unique count the null value also
len(temp.unique())
# Out:
# 7

# %%
# no null values are taken here
temp.nunique()
# Out:
# 6

# %%
overall.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %% [markdown]
# ### Series using read_csv

# %% [markdown]
# subs = pd.read_csv('Bollywood.csv', index_col='', squeeze = True )

# %% [markdown]
# ### DataFrame

# %%
#using list
student_data = [
    [100,80,10],
    [90,70, 7],
    [120,80,2]
]
pd.DataFrame(student_data, columns = ['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120     80        2

# %%
#using dictionary
stu_dic = {'iq': [100,90,84,22],
          'marks': [80,70,100,50],
          'package':[10,7,14,2]
          }
students = pd.DataFrame(stu_dic)
stu_dic
# Out:
# {'iq': [100, 90, 84, 22],
#  'marks': [80, 70, 100, 50],
#  'package': [10, 7, 14, 2]}

# %%
# making dataframe using dictionary
stu = {
    'name':['Rahul','Vivek','Swayam','Rohit','Ram'],
    'iq':[100,90,120,80,0],
    'marks':[61,69,56,77,99],
    'package':[10,7,4,6,9]
}
students = pd.DataFrame(stu)
# Set 'name' as the index
students.set_index('name', inplace=True)

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/rahul/Python_Programming/Revise/Libraries/Pandas/titanic/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Finding the number of null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Finding the duplicate value
duplicates = df.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
df.value_counts('Survived')
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Statistical 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df = df.dropna(subset=['Cabin'])

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_26516\1841944837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %% [markdown]
# #### 1. Remove Null Values
#
# - Method	What it Does
# - df.dropna()	Removes all rows with any null values
# - df.dropna(axis=1)	Removes columns with any null values
# - df.dropna(how='all')	Drops rows where all columns are NaN
# - df.dropna(subset=['col1', 'col2'])	Drops rows where certain columns are NaN

# %% [markdown]
# #### 2. Fill / Replace Null Values
#
# - Method	What it Does
# - df.fillna(0)	Replaces all nulls with 0
# - df.fillna('missing')	Replaces all nulls with text
# - df.fillna(method='ffill')	Forward fills (uses previous non-null value)
# - df.fillna(method='bfill')	Backward fills (uses next non-null value)
# - df.fillna(df['col'].mean())	Fills with mean value of a column
# - df.fillna(df['col'].median())	Fills with median value
# - df.fillna(df['col'].mode()[0])	Fills with mode (most frequent value)

# %%
# sort_values() requires a column name (or list of columns) to know based on what it should sort.
df.sort_values(by='Age', inplace=True)
df
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_26516\4060436646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by='Age', inplace=True)
#      PassengerId  Survived  Pclass                                  Name  \
# 305          306         1       1        Allison, Master. Hudson Trevor
# 183          184         1       2             Becker, Master. Richard F
# 297          298         0       1          Allison, Miss. Helen Loraine
# 205          206         0       3            Strom, Miss. Telma Matilda
# 340          341         1       2        Navratil, Master. Edmond Roger
# ..           ...       ...     ...                                   ...
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ...

# %%
df.sort_index(inplace = True)

# %%
df['Cabin'].count()
# Out:
# np.int64(204)

# %%
# Encoding sex columns
df['Sex'] = df['Sex'].apply(lambda x:1 if x=='male' else 0)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_26516\723855990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex'] = df['Sex'].apply(lambda x:1 if x=='male' else 0)

# %% [markdown]
# df['Sex] = df['Sex].map({'male':1, 'female':0})
# df['Sex'] = df['Sex'].str.lower().map({'male': 1, 'female': 0})
# df['Sex'] = df['Sex'].replace({'male':1, 'female':0})

# %%
df['Sex'].mean()
# Out:
# np.float64(0.5245098039215687)

# %% [markdown]
# df[''].median()
# df[''].mode()

# %%
df['Name'].mode()
# Out:
# 0                        Allen, Miss. Elisabeth Walton
# 1                       Allison, Master. Hudson Trevor
# 2                         Allison, Miss. Helen Loraine
# 3      Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 4                                  Anderson, Mr. Harry
#                             ...
# 199                           Wick, Miss. Mary Natalie
# 200                          Widener, Mr. Harry Elkins
# 201             Williams-Lambert, Mr. Fletcher Fellows
# 202                                  Woolner, Mr. Hugh
# 203                           Young, Miss. Marie Grice
# Name: Name, Length: 204, dtype: object

# %% [markdown]
# #### Splitting column 'Name' into 2 section

# %%
df[['LastName', 'Rest']] = df['Name'].str.split(',', expand=True)
df
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_26516\3781814883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['LastName', 'Rest']] = df['Name'].str.split(',', expand=True)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_26516\3781814883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['LastName', 'Rest']] = df['Name'].str.split(',', expand=True)
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# ...

# %% [markdown]
# #### Dropping the column 'Name'

# %%
df = df.drop(columns= ['Name'])
df
# Out:
#      PassengerId  Survived  Pclass  Sex    Age  SibSp  Parch     Ticket  \
# 305          306         1       1    1   0.92      1      2     113781
# 183          184         1       2    1   1.00      2      1     230136
# 297          298         0       1    0   2.00      1      2     113781
# 205          206         0       3    0   2.00      0      1     347054
# 340          341         1       2    1   2.00      1      1     230080
# ..           ...       ...     ...  ...    ...    ...    ...        ...
# 54            55         0       1    1  65.00      0      1     113509
# 456          457         0       1    1  65.00      0      0      13509
# 745          746         0       1    1  70.00      1      1  WE/P 5735
# 96            97         0       1    1  71.00      0      0   PC 17754
# 630          631         1       1    1  80.00      0      0      27042
#
#          Fare    Cabin Embarked     LastName                        Rest
# ...

# %%
''' Changing column name'''
df = df.rename(columns={'LastName':'SurName'})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex    Age  SibSp  Parch     Ticket  \
# 305          306         1       1    1   0.92      1      2     113781
# 183          184         1       2    1   1.00      2      1     230136
# 297          298         0       1    0   2.00      1      2     113781
# 205          206         0       3    0   2.00      0      1     347054
# 340          341         1       2    1   2.00      1      1     230080
# ..           ...       ...     ...  ...    ...    ...    ...        ...
# 54            55         0       1    1  65.00      0      1     113509
# 456          457         0       1    1  65.00      0      0      13509
# 745          746         0       1    1  70.00      1      1  WE/P 5735
# 96            97         0       1    1  71.00      0      0   PC 17754
# 630          631         1       1    1  80.00      0      0      27042
#
#          Fare    Cabin Embarked      SurName                        Rest
# ...

# %%
df['Fare'].plot()
# Out:
# <Axes: >

# %%
# Fetching single column
df['SurName']
# Out:
# 305        Allison
# 183         Becker
# 297        Allison
# 205          Strom
# 340       Navratil
#           ...
# 54           Ostby
# 456         Millet
# 745         Crosby
# 96     Goldschmidt
# 630      Barkworth
# Name: SurName, Length: 204, dtype: object

# %% [markdown]
# ### Selection using
# - 1. iloc:- It uses index position, find elements from start to end-1.
# - 2. loc:- It uses index name, find element from start to end.

# %%
df.sort_index()
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch    Ticket  \
# 1              2         1       1    0  38.0      1      0  PC 17599
# 3              4         1       1    0  35.0      1      0    113803
# 6              7         0       1    1  54.0      0      0     17463
# 10            11         1       3    0   4.0      1      1   PP 9549
# 11            12         1       1    0  58.0      0      0    113783
# ..           ...       ...     ...  ...   ...    ...    ...       ...
# 871          872         1       1    0  47.0      1      1     11751
# 872          873         0       1    1  33.0      0      0       695
# 879          880         1       1    0  56.0      0      1     11767
# 887          888         1       1    0  19.0      0      0    112053
# 889          890         1       1    1  26.0      0      0    111369
#
#         Fare        Cabin Embarked    SurName  \
# 1    71.2833          C85        C    Cumings
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.iloc[0:11]
# Out:
#     PassengerId  Survived  Pclass  Sex    Age  SibSp  Parch   Ticket  \
# 0           306         1       1    1   0.92      1      2   113781
# 1           184         1       2    1   1.00      2      1   230136
# 2           298         0       1    0   2.00      1      2   113781
# 3           206         0       3    0   2.00      0      1   347054
# 4           341         1       2    1   2.00      1      1   230080
# 5           194         1       2    1   3.00      1      1   230080
# 6            11         1       3    0   4.00      1      1  PP 9549
# 7           446         1       1    1   4.00      0      2    33638
# 8           619         1       2    0   4.00      2      1   230136
# 9           752         1       3    1   6.00      0      1   392096
# 10          803         1       1    1  11.00      1      2   113760
#
#         Fare    Cabin Embarked    SurName                          Rest
# ...

# %%
df.iloc[0]
# Out:
# PassengerId                       306
# Survived                            1
# Pclass                              1
# Sex                                 1
# Age                              0.92
# SibSp                               1
# Parch                               2
# Ticket                         113781
# Fare                           151.55
# Cabin                         C22 C26
# Embarked                            S
# SurName                       Allison
# Rest            Master. Hudson Trevor
# Name: 0, dtype: object

# %%
df.loc[3:8]
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch   Ticket     Fare  \
# 3          206         0       3    0  2.0      0      1   347054  10.4625
# 4          341         1       2    1  2.0      1      1   230080  26.0000
# 5          194         1       2    1  3.0      1      1   230080  26.0000
# 6           11         1       3    0  4.0      1      1  PP 9549  16.7000
# 7          446         1       1    1  4.0      0      2    33638  81.8583
# 8          619         1       2    0  4.0      2      1   230136  39.0000
#
#   Cabin Embarked    SurName                   Rest
# 3    G6        S      Strom    Miss. Telma Matilda
# 4    F2        S   Navratil   Master. Edmond Roger
# 5    F2        S   Navratil       Master. Michel M
# 6    G6        S  Sandstrom   Miss. Marguerite Rut
# 7   A34        S      Dodge     Master. Washington
# 8    F4        S     Becker    Miss. Marion Louise

# %% [markdown]
# #### No. of survivor based on gender(male)

# %%
df[(df['Survived'] == 1) & (df['Sex'] == 1)].shape[0]
# Out:
# 45

# %%
# Group by 'Sex' and sum 'Survived'
survivors_by_gender = df.groupby('Sex')['Survived'].sum()
print(survivors_by_gender)
# Out:
# Sex
# 0    91
# 1    45
# Name: Survived, dtype: int64

# %% [markdown]
# ### Euclidean distance

# %%
def euclidean(row):
  pt_A = row['1st point']
  pt_B = row['2nd point']

  return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
points_df['distance'] = points_df.apply(euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
